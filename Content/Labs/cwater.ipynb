# %% [markdown]
# # Bepaling van soortelijke warmte van water

# %% [markdown]
# # Introductie
#
# Water heeft een enorme buffercapaciteit: je moet veel energie toevoegen om de temperatuur van water een graad te verwarmen. In dit practicum gaan we de soortelijke warmte van water bepalen door een bekende hoeveelheid water te verwarmen met een bekende hoeveelheid energie, en de temperatuurstijging te meten.

# %% [markdown]
# # Theorie
#
# basis formule voor dit experiment: De hoeveelheid warmte-energie ($Q$) die nodig is om de temperatuur van een stof te veranderen, is recht evenredig met de massa ($m$) van de stof en de temperatuurverandering ($\Delta T$). De evenredigheidsconstante is de soortelijke warmtecapaciteit ($c$).$$\text{Warmte-energie:} \quad Q = m \cdot c \cdot \Delta T$$
# In dit experiment wordt de warmte-energie ($Q$) elektrisch geleverd door een verwarmingselement (weerstand) dat is aangesloten op een voedingsbron.
#
# De elektrische energie die wordt omgezet in warmte is gelijk aan het product van het elektrisch vermogen ($P$) en de tijd ($t$).$$\text{Elektrische energie:} \quad Q_{\text{elektrisch}} = P \cdot t$$Het elektrisch vermogen ($P$) wordt berekend uit de spanning ($V$) over de weerstand en de stroomsterkte ($I$) erdoorheen: $P = V \cdot I$.$$\text{Dus:} \quad Q_{\text{elektrisch}} = V \cdot I \cdot t$$
#
# Door de toegevoerde elektrische energie gelijk te stellen aan de opgenomen warmte-energie van het water (idealiter, zonder warmteverlies):$$V \cdot I \cdot t = m \cdot c \cdot \Delta T$$De soortelijke warmte van water ($c$) kan dan worden berekend door de formule om te schrijven:$$c = \frac{V \cdot I \cdot t}{m \cdot \Delta T}$$

# %% [markdown]
# # Methode en materialen
#
# ## Ontwerp
# Een waterbad met bekende massa aan water wordt verwarmd met een elektrisch verwarmingselement dat een bekende hoeveelheid energie levert.
# De temperatuur van het water wordt gemeten met een temperatuursensor.
# Door de temperatuurstijging als functie van de tijd te meten kan de soortelijke warmte van water worden berekend.
#
#
# ## Materialen
# Hieronder staat de lijst van benodigde materialen bij deze proef:
# - Maatbeker
# - Weegschaal
# - Water
# - Elektrisch verwarmingselement ($10 \mathrm{\Omega}$, $10 \mathrm{W}$)
# - Voedingsbron
# - Thermometer of temperatuursensor
# - Stopwatch of timer
#
# ```{figure} figures/cwater_setup.jpg
# :width: 70%
#
# Een schematische weergave van de opstelling
# ```
#
# ## Procedure
# ```{exercise}
# 1. Beschrijf de procedure die nodig is om de soortelijke warmte van water te bepalen.
# 2. Geef jouw beschrijving van de procedure aan een ander team, zij verzamelen voor jou de data op basis van de gegevens.
# 3. Voer het experiment van een ander team uit op basis van hun beschrijving.
# 4. Analyseer de data die het andere groepje voor jou heeft verzameld.
# ```
# Voorbereiding:
# 1. Weeg de massa ($m$): Bepaal de massa van de lege maatbeker. Voeg een bekende hoeveelheid water toe en weeg opnieuw. Bereken de massa ($m$) van het water.
# 2. Bouw de opstelling: Plaats het water in de beker.
# 3. Installeer meetinstrumenten: Plaats het elektrische verwarmingselement en de temperatuursensor/thermometer in het water. Zorg ervoor dat het verwarmingselement volledig ondergedompeld is.
# 4. Sluit de stroomkring aan: Sluit de voedingsbron aan op het verwarmingselement. Sluit een voltmeter (parallel) en een ampèremeter (serie) aan om de spanning ($V$) en stroomsterkte ($I$) te meten (of gebruik een multimeter die beide kan meten).
#
# Meting:
# 1. Meet de starttemperatuur ($T_{\text{start}}$): Meet en noteer de temperatuur van het water. Dit is de initiële temperatuur.
# 2. Start het verwarmen: Schakel de voedingsbron in en start tegelijkertijd de stopwatch ($t=0$).
# 3. Controleer en registreer $V$ en $I$: Noteer de spanning ($V$) en stroomsterkte ($I$) die door het verwarmingselement lopen. Dit is nodig om het vermogen ($P = V \cdot I$) te berekenen.
# 4. Roeren: Roer het water constant, of schakel een roerder in, om een gelijkmatige warmteverdeling te garanderen.Data verzamelen: Meet en noteer de temperatuur ($T$) van het water met regelmatige tijdsintervallen (bijv. elke 30 of 60 seconden) gedurende de vooraf bepaalde meettijd (bijv. 10 tot 15 minuten).Stop het experiment: Schakel na de gewenste tijd ($t_{\text{eind}}$) de stroom uit. Noteer de totale verstreken tijd ($t$) en de uiteindelijke temperatuur ($T_{\text{eind}}$).
#
# ## Veiligheid
# We maken gebruik van een $10 \mathrm{\Omega}$, $10 \mathrm{W}$ weerstand.
# Deze wordt snel heet.
# De bronspanning mag dan ook alleen aan wanneer de weerstand in het water zit.
# Raak de weerstand niet aan tijdens het experiment.
# Omdat de weerstand in het water zit, kunnen we wel het elektrisch vermogen hoger zetten zonder dat de weerstand oververhit raakt.
# Het maximaal vermogen mag $40 \mathrm{W}$ zijn.
# Daarbij moet de roerder wel aanstaan om de warmte goed te verdelen.
#
# ## Data analyse
# Geef kort de data-analysemethode weer.
#
# 1. Bereken $\Delta T$: Bereken de totale temperatuurstijging $\Delta T = T_{\text{eind}} - T_{\text{start}}$.
# 2. Bereken $Q$: Bereken de totale toegevoegde warmte-energie met $Q = V \cdot I \cdot t$.
# 3. Bereken $c$: Vul alle gemeten waarden in de formule in om de soortelijke warmte van water ($c$) te bepalen:$$c = \frac{Q}{m \cdot \Delta T} = \frac{V \cdot I \cdot t}{m \cdot \Delta T}$$

# %% [markdown]
# # Resultaten

# %%
# Hier de data en de analyse
dT = ([])

Q = ([])* V * I
c = Q / (m * dT)

# %%
# Sla figuren op met  
# 
# plt.savefig("figures/naam.png", dpi=450)

# %% [markdown]
# # Discussie en conclusie
#
# Hier een korte discussie en conclusie over de resultaten van het experiment en de implicaties daarvan.
